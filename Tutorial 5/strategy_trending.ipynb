# %%
import sys
import os

import ccxt
import backtesting as bt
from backtesting import Backtest, Strategy
import talib
import pandas_ta as ta

import pandas as pd
import numpy as np

# %%
def get_data(symbol, timeframe, limit):
    exchange = ccxt.kraken()
    exchange.load_markets()

    data = exchange.fetch_ohlcv('BTC/USDT', timeframe=timeframe, limit=limit)
    df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume']).rename(columns={
        'timestamp': 'timestamp',
        'open': 'Open',
        'high': 'High',
        'low': 'Low',
        'close': 'Close',
        'volume': 'Volume'
    })
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)
    return df

# %%
data = get_data('BTC/USDT', '1h', 1000)

# %%
data
# Out:
#                         Open     High      Low    Close    Volume
# timestamp
# 2024-04-27 03:00:00  62947.0  63136.9  62841.0  63070.6  3.890570
# 2024-04-27 04:00:00  63049.1  63161.5  62957.3  63013.3  0.562865
# 2024-04-27 05:00:00  63029.9  63073.0  62857.5  62981.3  0.806780
# 2024-04-27 06:00:00  62981.2  63110.7  62890.0  63005.0  1.887178
# 2024-04-27 07:00:00  63006.9  63139.2  62950.6  62965.5  6.454611
# ...                      ...      ...      ...      ...       ...
# 2024-05-26 22:00:00  68494.7  68693.6  68481.9  68595.6  3.915592
# 2024-05-26 23:00:00  68559.7  68559.8  68356.7  68531.7  1.545142
# 2024-05-27 00:00:00  68503.1  68762.1  68476.7  68756.5  1.062076
# 2024-05-27 01:00:00  68762.1  69241.3  68740.0  69140.0  1.255163
# 2024-05-27 02:00:00  69079.1  69269.0  69026.4  69169.4  0.283014
#
# [720 rows x 5 columns]

# %% [markdown]
# # EMA strategy

# %%
class EMA_strategy(Strategy):
    ############################ Parameters ####################################
    ema_a = 36
    ema_b = 60

    ############################ Utilities ####################################
    # For logging
    def log(self, txt, dt=None):
        dt = dt or self.data.index[-1]
        # print(f'{dt.strftime("%Y-%m-%d %H:%M:%S")}: {txt}')
    
    ############################ Strategy: Calculate the indicators ####################################

    def init(self):
        
        # print(f"BB_SMA: {self.BB_SMA}, BB_STD: {self.BB_STD}, BB_MAX_BANDWIDTH: {self.BB_MAX_BANDWIDTH}")
        # print(f"min_volatility: {self.min_volatility}, max_buy_perc: {self.max_buy_perc}, min_sell_perc: {self.min_sell_perc}")
        
        self.line_a = self.I(lambda df, length: df.ta.ema(close = df['Close'], length=length), self.data.df, self.ema_a, name='line_a')
        self.line_b = self.I(lambda df, length: df.ta.ema(close = df['Close'], length=length), self.data.df, self.ema_b, name='line_b')
        
        self.buy_signal = self.I(lambda line_a, line_b: (line_a > line_b), self.line_a, self.line_b, name='buy_signal')
        self.sell_signal = self.I(lambda line_a, line_b: (line_a < line_b), self.line_a, self.line_b, name='sell_signal')
    def next(self):
        
        self.log(f"Close: {self.data.Close[-1]}, position: {self.position.size}, cash: {self._broker.margin_available}")
        
        if self._broker.orders:
            return
        
        if self.position.size == 0:
            if self.buy_signal[-1]:
                self.log("BUY")
                self.buy()
                
            elif self.sell_signal[-1]:
                self.log("SELL")
                self.sell()
                
        elif self.position.size > 0:
            if self.sell_signal[-1]:
                self.log("Close BUY")
                self.position.close()
                
                self.log("SELL")
                self.sell()
                
        elif self.position.size < 0:
            if self.buy_signal[-1]:
                self.log("Close SELL")
                self.position.close()
                
                self.log("BUY")
                self.buy()

# %%
bt = Backtest(
    data, 
    EMA_strategy,
    commission=0.00075, 
    cash=100000, 
    )

strat = bt.run() 
bt.plot()
# Out:
# Row(id='1566', ...)

# %%
pd.DataFrame(strat)
# Out:
#                                                                         0
# Start                                                 2024-04-27 03:00:00
# End                                                   2024-05-27 02:00:00
# Duration                                                 29 days 23:00:00
# Exposure Time [%]                                               91.527778
# Equity Final [$]                                             98251.955875
# Equity Peak [$]                                             106107.023225
# Return [%]                                                      -1.748044
# Buy & Hold Return [%]                                            9.669799
# Return (Ann.) [%]                                              -18.749908
# Volatility (Ann.) [%]                                           27.582868
# Sharpe Ratio                                                          0.0
# Sortino Ratio                                                         0.0
# Calmar Ratio                                                          0.0
# Max. Drawdown [%]                                              -11.039892
# Avg. Drawdown [%]                                               -1.940144
# Max. Drawdown Duration                                   25 days 11:00:00
# Avg. Drawdown Duration                                    3 days 10:00:00
# # Trades                                                               10
# Win Rate [%]                                                         30.0
# Best Trade [%]                                                   8.672825
# Worst Trade [%]                                                 -3.606796
# Avg. Trade [%]                                                   -0.32036
# Max. Trade Duration                                       8 days 10:00:00
# Avg. Trade Duration                                       2 days 18:00:00
# Profit Factor                                                    0.821424
# Expectancy [%]                                                  -0.261432
# SQN                                                             -0.240865
# _strategy                                                    EMA_strategy
# _equity_curve                                       Equity  DrawdownPc...
# _trades                    Size  EntryBar  ExitBar    EntryPrice  Exit...

# %% [markdown]
# ## Optimization

# %%
import multiprocessing as mp
mp.set_start_method('fork')

# %%
bt = Backtest(
    data, 
    EMA_strategy,
    commission=0.00075, 
    cash=100000, 
    )

stats = bt.optimize(
                    ema_a=range(5, 70, 1), # 5-70 
                    ema_b=range(5, 70, 1), # 5-70
                    constraint=lambda param: param.ema_a < param.ema_b,
                    maximize='Sharpe Ratio',
                    max_tries=500,
                    random_state=1) 

pd.DataFrame(stats)
stats._strategy
# Out:
# /Users/cholian/anaconda3/envs/tokenmetrics/lib/python3.10/site-packages/backtesting/backtesting.py:1488: UserWarning: Searching for best of 501 configurations.
#   output = _optimize_grid()
# Backtest.optimize:   0%|          | 0/11 [00:00<?, ?it/s]
# <Strategy EMA_strategy(ema_a=13,ema_b=17)>

# %%
bt = Backtest(
    data, 
    EMA_strategy,
    commission=0.00075, 
    cash=100000, 
    )

strat = bt.run(ema_a=13, ema_b=17)
bt.plot()
# Out:
# Row(id='2784', ...)

# %%
strat
# Out:
# Start                     2024-04-27 03:00:00
# End                       2024-05-27 02:00:00
# Duration                     29 days 23:00:00
# Exposure Time [%]                        97.5
# Equity Final [$]                 104863.06085
# Equity Peak [$]                 108529.646825
# Return [%]                           4.863061
# Buy & Hold Return [%]                9.669799
# Return (Ann.) [%]                   71.342725
# Volatility (Ann.) [%]               51.684928
# Sharpe Ratio                         1.380339
# Sortino Ratio                        4.296442
# Calmar Ratio                        10.777848
# Max. Drawdown [%]                   -6.619385
# Avg. Drawdown [%]                   -1.386133
# Max. Drawdown Duration       14 days 15:00:00
# Avg. Drawdown Duration        1 days 23:00:00
# # Trades                                   26
# Win Rate [%]                        30.769231
# Best Trade [%]                       7.980765
# Worst Trade [%]                     -2.232252
# Avg. Trade [%]                       0.295547
# Max. Trade Duration           4 days 02:00:00
# Avg. Trade Duration           1 days 03:00:00
# Profit Factor                        1.479751
# Expectancy [%]                       0.324376
# SQN                                  0.623598
# _strategy                 EMA_strategy(ema...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
strat._trades
# Out:
#     Size  EntryBar  ExitBar    EntryPrice  ExitPrice          PnL  ReturnPct  \
# 0      1        18       45  63324.858050    63106.3  -218.558050  -0.003451
# 1     -1        45       67  63058.970275    63087.8   -28.829725  -0.000457
# 2      1        67       78  63135.115850    61868.4 -1266.715850  -0.020064
# 3     -1        78      130  61821.998700    58558.0  3263.998700   0.052797
# 4      1       130      228  58601.918500    63278.8  4676.881500   0.079808
# 5     -1       228      246  63231.340900    64233.2 -1001.859100  -0.015844
# 6      1       246      251  64281.374900    63197.2 -1084.174900  -0.016866
# 7     -1       251      252  63149.802100    64033.1  -883.297900  -0.013987
# 8      1       252      255  64081.124825    63380.4  -700.724825  -0.010935
# 9     -1       255      304  63332.864700    62257.8  1075.064700   0.016975
# 10     1       304      325  62304.493350    60913.7 -1390.793350  -0.022323
# 11    -1       325      368  60868.014725    61149.9  -281.885275  -0.004631
# 12     1       368      387  61195.762425    60858.7  -337.062425  -0.005508
# 13    -1       387      388  60813.055975    61500.0  -686.944025  -0.011296
# 14     1       388      413  61546.125000    62026.2   480.075000   0.007800
# 15    -1       413      437  61979.680350    62189.8  -210.119650  -0.003390
# 16     1       437      474  62236.442350    65252.0  3015.557650   0.048453
# 17    -1       474      484  65203.061000    65954.0  -750.939000  -0.011517
# 18     1       484      542  66003.465500    66657.5   654.034500   0.009909
# 19    -1       542      559  66607.506875    66890.7  -283.193125  -0.004252
# 20     1       559      593  66940.868025    69295.8  2354.931975   0.035179
# 21    -1       593      614  69243.828150    70229.9  -986.071850  -0.014241
# 22     1       614      616  70282.572425    69577.7  -704.872425  -0.010029
# 23    -1       616      663  69525.516725    68885.1   640.416725   0.009211
# 24     1       663      710  68936.763825    68792.8  -143.963825  -0.002088
# 25    -1       710      719  68741.205400    69079.1  -337.894600  -0.004915
#
#              EntryTime            ExitTime        Duration
